# %%
# !pip install nltk
# !pip install openai nltk rouge
# Out:
# Requirement already satisfied: nltk in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from nltk) (2024.4.28)
# Requirement already satisfied: tqdm in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: openai in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (1.34.0)
# Requirement already satisfied: nltk in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (3.8.1)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: click in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from nltk) (2024.4.28)
# Requirement already satisfied: six in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from rouge) (1.16.0)
# Requirement already satisfied: idna>=2.8 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Requirement already satisfied: colorama in c:\users\engrd\anaconda3\envs\mcq-ece\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge import Rouge

# %%
# Reference and generated questions
references = [
    ["A signal that repeats at a uniform rate. Periodic Wave"],
    ["A time-domain instrument that shows signal waveforms. Oscilloscope"],
    ["It is used in signal analysis to represent the sinusoidal components of nonsinusoidal periodic waveforms. Fourier Series"],
    ["A description of signal with respect to its frequency. Frequency Domain Representation"],
    ["Is the mathematical analysis of the frequency, bandwidth, and voltage level of a signal. Signal Analysis"],
    ["Contamination by extraneous or external signals from human sources, other transmitters, power lines, machinery, switching circuits, and related sources is known as: Interference"],
    ["Degradation of signal strength as a signal propagates through the medium is called: Attenuation"],
    ["Noise radiated from distant stars and other heavenly bodies is referred to as: Cosmic Noise"],
    ["Noise caused by random variations in the arrival of electrons at the output electrode of an amplifying device is known as: Shot"],
    ["A pulse-width modulation system used for telegraphy can be achieved by: Using a monostable"],
    ["Digital signals: all of the above"],
    ["The event which marked the start of the modern computer age was: development of the transistor"],
    ["The baud rate: is equal to twice the bandwidth of an ideal channel"],
    ["The Shannon-Hartley law: refers to noise"],
    ["_______ uses a single bit PCM code to achieve a digital transmission of an analog signal. Delta modulation"],
    ["In a transmission line, if the SWR or maximum current to a minimum current ratio is 2:1, what is the ratio of the maximum voltage to the minimum voltage? 2:1"],
    ["What device is used to make the antenna, transmission line, and transmitter impedance match? Tuner"],
    ["To connect a coaxial line to a parallel-wire line, which of the following is best to use? Balun"],
    ["Which of the following provides transmission and switching of telecommunications services, primarily for voice communication, within a geographic area? Franchise"],
    ["What is a good method of increasing radiation resistance by having a horizontal portion at the top of the antenna? Top loading"],    
    ["What is the largest frequency that will be returned to earth when transmitted vertically under given ionospheric conditions? Critical frequency"],
    ["What type of propagation typically occurs between two hand-held VHF transceivers that are in close proximity? Line-of-sight propagation"],
    ["How does the range of sky-wave propagation compare to ground-wave propagation? It is much longer"],
    ["What type of propagation would best be used by two stations within each other's skip zone on a certain frequency? Ground-wave"],
    ["Which of the following is a disadvantage of ground wave propagation? Any of these"],
    ["In the context of T-1 cables, which type of coding is used? Bipolar RZ AMI coding"],
    ["A system where one node holds all the application software is known as: Client-server networks"],
    ["In a CATV system, CMTS stands for: Cable Modem Terminal Server"],
    ["Which layer lies between the network layer and the application layer? Transport"],
    ["Which error detection method involves polynomials? CRC"]
]

candidates = [
    "What is the term for a signal that repeats at a uniform rate? Periodic Wave",
    "Which instrument is used to display signal waveforms with respect to time? Oscilloscope",
    "What represents the sinusoidal components of nonsinusoidal periodic waveforms? Fourier Series",
    "What is described by the term 'Frequency Domain Representation'? A description of signal with respect to frequency",
    "What is the mathematical analysis of the frequency, bandwidth, and voltage level of a signal? Signal Analysis",
    "Contamination by extraneous or external signals from human sources, other transmitters, power lines, machinery, switching circuits, and related sources. Interference",
    "Degradation of signal strength as a signal propagates through the medium. Attenuation",
    "Noise radiated from distant stars and other heavenly bodies. Cosmic Noise",
    "Noise caused by random variations in the arrival of electrons at the output electrode of an amplifying device. Shot",
    "Pulse-width modulation system used for telegraphy is. with a monostable",
    "Digital signals. all of the above",
    "The event which marked the start of the modern computer age was. development of the transistor",
    "The baud rate. is equal to twice the bandwidth of an ideal channel",
    "The Shannon-Hartley law. refers to noise",
    "_______ uses a single bit PCM code to achieve a digital transmission of analog signal. Delta modulation",
    "In a transmission line, if the SWR or maximum current to a minimum current ratio of 2:1, the ratio of the maximum voltage to the minimum voltage is. 2:1",
    "An impedance matching circuit used to make the antenna, transmission line and transmitter impedance match is the. Tuner",
    "To couple a coaxial line to a parallel-wire line, it is best to use a. balun",
    "An entity providing transmission and switching of telecommunications services, primarily but not limited to voice to voice, in a geographic area anywhere in the country. Franchise",
    "A good method of increasing radiation resistance by having a horizontal portion at the top of the antenna. Top loading",
    "The largest frequency that will be returned to earth when transmitted vertically under given ionospheric conditions is called the. Critical frequency",
    "What type of propagation usually occurs from one hand- held VHF transceiver to another nearby? Line-of-sight propagation",
    "How does the range of sky-wave propagation compare to ground- wave propagation? It is much longer",
    "What kind of propagation would best be used by two stations within each other's skip zone on a certain frequency? Ground-wave",
    "The disadvantage of groundwave propagation is. Any of these",
    "A T-1 cable uses: bipolar RZ AMI coding",
    "Using one node in the network to hold all the application software is done in: client-server networks",
    "In a CATV system, CMTS stands for: Cable Modem Terminal Server",
    "The layer lies between the network layer and the application layer. Transport",
    "Which error detection method involves polynomials? CRC"
]

# %%
def compute_bleu(reference_sentences, candidate_sentence):
    # Tokenize the sentences
    reference_tokens = [nltk.word_tokenize(ref) for ref in reference_sentences]
    candidate_tokens = nltk.word_tokenize(candidate_sentence)

    # Compute BLEU score
    smoothing_function = SmoothingFunction().method4
    score = sentence_bleu(reference_tokens, candidate_tokens, smoothing_function=smoothing_function)
    return score

# %%
def compute_rouge(reference_sentences, candidate_sentence):
    rouge = Rouge()
    # Convert list of reference sentences to a single string
    reference_str = ' '.join(reference_sentences)
    scores = rouge.get_scores(candidate_sentence, reference_str)
    return scores[0]  # return the first (and only) score dictionary

# %%
# Compute BLEU and ROUGE scores for each candidate question
bleu_scores = []
rouge_scores = []
for ref, cand in zip(references, candidates):
    bleu_score = compute_bleu(ref, cand)
    bleu_scores.append(bleu_score)
    print(f"BLEU score for '{cand}': {bleu_score:.4f}")
    
    rouge_score = compute_rouge(ref, cand)
    rouge_scores.append(rouge_score)
    print(f"ROUGE score for '{cand}': {rouge_score}")
    print()
# Out:
# BLEU score for 'What is the term for a signal that repeats at a uniform rate? Periodic Wave': 0.4121
# ROUGE score for 'What is the term for a signal that repeats at a uniform rate? Periodic Wave': {'rouge-1': {'r': 0.8, 'p': 0.5714285714285714, 'f': 0.6666666618055556}, 'rouge-2': {'r': 0.6666666666666666, 'p': 0.42857142857142855, 'f': 0.5217391256710776}, 'rouge-l': {'r': 0.8, 'p': 0.5714285714285714, 'f': 0.6666666618055556}}
#
# BLEU score for 'Which instrument is used to display signal waveforms with respect to time? Oscilloscope': 0.0491
# ROUGE score for 'Which instrument is used to display signal waveforms with respect to time? Oscilloscope': {'rouge-1': {'r': 0.5, 'p': 0.3333333333333333, 'f': 0.39999999520000007}, 'rouge-2': {'r': 0.14285714285714285, 'p': 0.08333333333333333, 'f': 0.10526315324099744}, 'rouge-l': {'r': 0.5, 'p': 0.3333333333333333, 'f': 0.39999999520000007}}
#
# BLEU score for 'What represents the sinusoidal components of nonsinusoidal periodic waveforms? Fourier Series': 0.3461
# ROUGE score for 'What represents the sinusoidal components of nonsinusoidal periodic waveforms? Fourier Series': {'rouge-1': {'r': 0.47058823529411764, 'p': 0.7272727272727273, 'f': 0.5714285666581633}, 'rouge-2': {'r': 0.375, 'p': 0.6, 'f': 0.4615384568047337}, 'rouge-l': {'r': 0.47058823529411764, 'p': 0.7272727272727273, 'f': 0.5714285666581633}}
#
# BLEU score for 'What is described by the term 'Frequency Domain Representation'? A description of signal with respect to frequency': 0.3503
# ROUGE score for 'What is described by the term 'Frequency Domain Representation'? A description of signal with respect to frequency': {'rouge-1': {'r': 0.75, 'p': 0.5294117647058824, 'f': 0.6206896503210465}, 'rouge-2': {'r': 0.5454545454545454, 'p': 0.375, 'f': 0.44444443961591223}, 'rouge-l': {'r': 0.75, 'p': 0.5294117647058824, 'f': 0.6206896503210465}}
#
# BLEU score for 'What is the mathematical analysis of the frequency, bandwidth, and voltage level of a signal? Signal Analysis': 0.7648
# ROUGE score for 'What is the mathematical analysis of the frequency, bandwidth, and voltage level of a signal? Signal Analysis': {'rouge-1': {'r': 0.8571428571428571, 'p': 0.8, 'f': 0.8275862019024971}, 'rouge-2': {'r': 0.8, 'p': 0.75, 'f': 0.7741935433922998}, 'rouge-l': {'r': 0.8571428571428571, 'p': 0.8, 'f': 0.8275862019024971}}
#
# BLEU score for 'Contamination by extraneous or external signals from human sources, other transmitters, power lines, machinery, switching circuits, and related sources. Interference': 0.8265
# ROUGE score for 'Contamination by extraneous or external signals from human sources, other transmitters, power lines, machinery, switching circuits, and related sources. Interference': {'rouge-1': {'r': 0.8695652173913043, 'p': 1.0, 'f': 0.9302325531638724}, 'rouge-2': {'r': 0.8181818181818182, 'p': 0.9473684210526315, 'f': 0.8780487755145747}, 'rouge-l': {'r': 0.8695652173913043, 'p': 1.0, 'f': 0.9302325531638724}}
#
# BLEU score for 'Degradation of signal strength as a signal propagates through the medium. Attenuation': 0.7222
# ROUGE score for 'Degradation of signal strength as a signal propagates through the medium. Attenuation': {'rouge-1': {'r': 0.8461538461538461, 'p': 1.0, 'f': 0.9166666617013889}, 'rouge-2': {'r': 0.7692307692307693, 'p': 0.9090909090909091, 'f': 0.8333333283680556}, 'rouge-l': {'r': 0.8461538461538461, 'p': 1.0, 'f': 0.9166666617013889}}
#
# BLEU score for 'Noise radiated from distant stars and other heavenly bodies. Cosmic Noise': 0.5511
# ROUGE score for 'Noise radiated from distant stars and other heavenly bodies. Cosmic Noise': {'rouge-1': {'r': 0.7142857142857143, 'p': 1.0, 'f': 0.8333333284722222}, 'rouge-2': {'r': 0.6428571428571429, 'p': 0.9, 'f': 0.7499999951388889}, 'rouge-l': {'r': 0.7142857142857143, 'p': 1.0, 'f': 0.8333333284722222}}
#
# BLEU score for 'Noise caused by random variations in the arrival of electrons at the output electrode of an amplifying device. Shot': 0.7777
# ROUGE score for 'Noise caused by random variations in the arrival of electrons at the output electrode of an amplifying device. Shot': {'rouge-1': {'r': 0.85, 'p': 1.0, 'f': 0.9189189139517896}, 'rouge-2': {'r': 0.8095238095238095, 'p': 0.9444444444444444, 'f': 0.8717948668244576}, 'rouge-l': {'r': 0.85, 'p': 1.0, 'f': 0.9189189139517896}}
#
# BLEU score for 'Pulse-width modulation system used for telegraphy is. with a monostable': 0.2805
# ROUGE score for 'Pulse-width modulation system used for telegraphy is. with a monostable': {'rouge-1': {'r': 0.5, 'p': 0.7, 'f': 0.5833333284722223}, 'rouge-2': {'r': 0.38461538461538464, 'p': 0.5555555555555556, 'f': 0.4545454497107439}, 'rouge-l': {'r': 0.5, 'p': 0.7, 'f': 0.5833333284722223}}
#
# BLEU score for 'Digital signals. all of the above': 0.4889
# ROUGE score for 'Digital signals. all of the above': {'rouge-1': {'r': 0.8333333333333334, 'p': 0.8333333333333334, 'f': 0.8333333283333335}, 'rouge-2': {'r': 0.6, 'p': 0.6, 'f': 0.5999999950000001}, 'rouge-l': {'r': 0.8333333333333334, 'p': 0.8333333333333334, 'f': 0.8333333283333335}}
#
# BLEU score for 'The event which marked the start of the modern computer age was. development of the transistor': 0.8282
# ROUGE score for 'The event which marked the start of the modern computer age was. development of the transistor': {'rouge-1': {'r': 0.9230769230769231, 'p': 0.9230769230769231, 'f': 0.9230769180769233}, 'rouge-2': {'r': 0.8571428571428571, 'p': 0.8571428571428571, 'f': 0.8571428521428571}, 'rouge-l': {'r': 0.9230769230769231, 'p': 0.9230769230769231, 'f': 0.9230769180769233}}
#
# BLEU score for 'The baud rate. is equal to twice the bandwidth of an ideal channel': 0.7825
# ROUGE score for 'The baud rate. is equal to twice the bandwidth of an ideal channel': {'rouge-1': {'r': 0.9230769230769231, 'p': 0.9230769230769231, 'f': 0.9230769180769233}, 'rouge-2': {'r': 0.8333333333333334, 'p': 0.8333333333333334, 'f': 0.8333333283333335}, 'rouge-l': {'r': 0.9230769230769231, 'p': 0.9230769230769231, 'f': 0.9230769180769233}}
#
# BLEU score for 'The Shannon-Hartley law. refers to noise': 0.3247
# ROUGE score for 'The Shannon-Hartley law. refers to noise': {'rouge-1': {'r': 0.8333333333333334, 'p': 0.8333333333333334, 'f': 0.8333333283333335}, 'rouge-2': {'r': 0.6, 'p': 0.6, 'f': 0.5999999950000001}, 'rouge-l': {'r': 0.8333333333333334, 'p': 0.8333333333333334, 'f': 0.8333333283333335}}
#
# BLEU score for '_______ uses a single bit PCM code to achieve a digital transmission of analog signal. Delta modulation': 0.8522
# ROUGE score for '_______ uses a single bit PCM code to achieve a digital transmission of analog signal. Delta modulation': {'rouge-1': {'r': 0.9411764705882353, 'p': 1.0, 'f': 0.9696969647015611}, 'rouge-2': {'r': 0.8823529411764706, 'p': 0.9375, 'f': 0.9090909040955004}, 'rouge-l': {'r': 0.9411764705882353, 'p': 1.0, 'f': 0.9696969647015611}}
#
# BLEU score for 'In a transmission line, if the SWR or maximum current to a minimum current ratio of 2:1, the ratio of the maximum voltage to the minimum voltage is. 2:1': 0.7622
# ROUGE score for 'In a transmission line, if the SWR or maximum current to a minimum current ratio of 2:1, the ratio of the maximum voltage to the minimum voltage is. 2:1': {'rouge-1': {'r': 0.9, 'p': 1.0, 'f': 0.9473684160664821}, 'rouge-2': {'r': 0.7586206896551724, 'p': 0.8148148148148148, 'f': 0.7857142807206633}, 'rouge-l': {'r': 0.85, 'p': 0.9444444444444444, 'f': 0.8947368371191137}}
#
# BLEU score for 'An impedance matching circuit used to make the antenna, transmission line and transmitter impedance match is the. Tuner': 0.4903
# ROUGE score for 'An impedance matching circuit used to make the antenna, transmission line and transmitter impedance match is the. Tuner': {'rouge-1': {'r': 0.7333333333333333, 'p': 0.6875, 'f': 0.7096774143600416}, 'rouge-2': {'r': 0.5, 'p': 0.4117647058823529, 'f': 0.4516128982726327}, 'rouge-l': {'r': 0.6666666666666666, 'p': 0.625, 'f': 0.6451612853277836}}
#
# BLEU score for 'To couple a coaxial line to a parallel-wire line, it is best to use a. balun': 0.4819
# ROUGE score for 'To couple a coaxial line to a parallel-wire line, it is best to use a. balun': {'rouge-1': {'r': 0.5625, 'p': 0.6923076923076923, 'f': 0.6206896502259216}, 'rouge-2': {'r': 0.47058823529411764, 'p': 0.5333333333333333, 'f': 0.49999999501953135}, 'rouge-l': {'r': 0.5625, 'p': 0.6923076923076923, 'f': 0.6206896502259216}}
#
# BLEU score for 'An entity providing transmission and switching of telecommunications services, primarily but not limited to voice to voice, in a geographic area anywhere in the country. Franchise': 0.3017
# ROUGE score for 'An entity providing transmission and switching of telecommunications services, primarily but not limited to voice to voice, in a geographic area anywhere in the country. Franchise': {'rouge-1': {'r': 0.631578947368421, 'p': 0.5, 'f': 0.5581395299513251}, 'rouge-2': {'r': 0.3684210526315789, 'p': 0.28, 'f': 0.31818181327479345}, 'rouge-l': {'r': 0.5789473684210527, 'p': 0.4583333333333333, 'f': 0.5116279020443484}}
#
# BLEU score for 'A good method of increasing radiation resistance by having a horizontal portion at the top of the antenna. Top loading': 0.7537
# ROUGE score for 'A good method of increasing radiation resistance by having a horizontal portion at the top of the antenna. Top loading': {'rouge-1': {'r': 0.8421052631578947, 'p': 0.8888888888888888, 'f': 0.8648648598685172}, 'rouge-2': {'r': 0.7619047619047619, 'p': 0.8421052631578947, 'f': 0.7999999950125001}, 'rouge-l': {'r': 0.8421052631578947, 'p': 0.8888888888888888, 'f': 0.8648648598685172}}
#
# BLEU score for 'The largest frequency that will be returned to earth when transmitted vertically under given ionospheric conditions is called the. Critical frequency': 0.7094
# ROUGE score for 'The largest frequency that will be returned to earth when transmitted vertically under given ionospheric conditions is called the. Critical frequency': {'rouge-1': {'r': 0.8947368421052632, 'p': 0.85, 'f': 0.8717948667981592}, 'rouge-2': {'r': 0.7368421052631579, 'p': 0.7, 'f': 0.7179487129520054}, 'rouge-l': {'r': 0.7894736842105263, 'p': 0.75, 'f': 0.7692307642340566}}
#
# BLEU score for 'What type of propagation usually occurs from one hand- held VHF transceiver to another nearby? Line-of-sight propagation': 0.1959
# ROUGE score for 'What type of propagation usually occurs from one hand- held VHF transceiver to another nearby? Line-of-sight propagation': {'rouge-1': {'r': 0.4117647058823529, 'p': 0.4375, 'f': 0.42424241924701567}, 'rouge-2': {'r': 0.23529411764705882, 'p': 0.25, 'f': 0.2424242374288339}, 'rouge-l': {'r': 0.4117647058823529, 'p': 0.4375, 'f': 0.42424241924701567}}
#
# BLEU score for 'How does the range of sky-wave propagation compare to ground- wave propagation? It is much longer': 0.7625
# ROUGE score for 'How does the range of sky-wave propagation compare to ground- wave propagation? It is much longer': {'rouge-1': {'r': 0.9333333333333333, 'p': 0.875, 'f': 0.9032258014568159}, 'rouge-2': {'r': 0.8571428571428571, 'p': 0.8, 'f': 0.8275862019024971}, 'rouge-l': {'r': 0.9333333333333333, 'p': 0.875, 'f': 0.9032258014568159}}
#
# BLEU score for 'What kind of propagation would best be used by two stations within each other's skip zone on a certain frequency? Ground-wave': 0.9173
# ROUGE score for 'What kind of propagation would best be used by two stations within each other's skip zone on a certain frequency? Ground-wave': {'rouge-1': {'r': 0.9523809523809523, 'p': 0.9523809523809523, 'f': 0.9523809473809525}, 'rouge-2': {'r': 0.9, 'p': 0.9, 'f': 0.899999995}, 'rouge-l': {'r': 0.9523809523809523, 'p': 0.9523809523809523, 'f': 0.9523809473809525}}
#
# BLEU score for 'The disadvantage of groundwave propagation is. Any of these': 0.1067
# ROUGE score for 'The disadvantage of groundwave propagation is. Any of these': {'rouge-1': {'r': 0.4166666666666667, 'p': 0.625, 'f': 0.4999999952000001}, 'rouge-2': {'r': 0.23076923076923078, 'p': 0.375, 'f': 0.28571428099773244}, 'rouge-l': {'r': 0.3333333333333333, 'p': 0.5, 'f': 0.39999999520000007}}
#
# BLEU score for 'A T-1 cable uses: bipolar RZ AMI coding': 0.0571
# ROUGE score for 'A T-1 cable uses: bipolar RZ AMI coding': {'rouge-1': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}, 'rouge-2': {'r': 0.13333333333333333, 'p': 0.2857142857142857, 'f': 0.18181817747933895}, 'rouge-l': {'r': 0.2857142857142857, 'p': 0.5, 'f': 0.36363635900826446}}
#
# BLEU score for 'Using one node in the network to hold all the application software is done in: client-server networks': 0.2462
# ROUGE score for 'Using one node in the network to hold all the application software is done in: client-server networks': {'rouge-1': {'r': 0.5333333333333333, 'p': 0.5, 'f': 0.5161290272632676}, 'rouge-2': {'r': 0.35714285714285715, 'p': 0.3125, 'f': 0.33333332835555557}, 'rouge-l': {'r': 0.5333333333333333, 'p': 0.5, 'f': 0.5161290272632676}}
#
# BLEU score for 'In a CATV system, CMTS stands for: Cable Modem Terminal Server': 1.0000
# ROUGE score for 'In a CATV system, CMTS stands for: Cable Modem Terminal Server': {'rouge-1': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-2': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-l': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}}
#
# BLEU score for 'The layer lies between the network layer and the application layer. Transport': 0.7539
# ROUGE score for 'The layer lies between the network layer and the application layer. Transport': {'rouge-1': {'r': 0.8, 'p': 0.8888888888888888, 'f': 0.8421052581717452}, 'rouge-2': {'r': 0.7272727272727273, 'p': 0.7272727272727273, 'f': 0.7272727222727273}, 'rouge-l': {'r': 0.8, 'p': 0.8888888888888888, 'f': 0.8421052581717452}}
#
# BLEU score for 'Which error detection method involves polynomials? CRC': 1.0000
# ROUGE score for 'Which error detection method involves polynomials? CRC': {'rouge-1': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-2': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-l': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}}

# %%
# Output average BLEU and ROUGE scores
avg_bleu_score = sum(bleu_scores) / len(bleu_scores)
print(f"Average BLEU score: {avg_bleu_score:.4f}")
# Out:
# Average BLEU score: 0.5632

# %%
avg_rouge_scores = {
    'rouge-1': {'f': 0, 'p': 0, 'r': 0},
    'rouge-2': {'f': 0, 'p': 0, 'r': 0},
    'rouge-l': {'f': 0, 'p': 0, 'r': 0}
}
for score in rouge_scores:
    for key in avg_rouge_scores:
        avg_rouge_scores[key]['f'] += score[key]['f']
        avg_rouge_scores[key]['p'] += score[key]['p']
        avg_rouge_scores[key]['r'] += score[key]['r']

for key in avg_rouge_scores:
    avg_rouge_scores[key]['f'] /= len(rouge_scores)
    avg_rouge_scores[key]['p'] /= len(rouge_scores)
    avg_rouge_scores[key]['r'] /= len(rouge_scores)

print(f"Average ROUGE scores: {avg_rouge_scores}")
# Out:
# Average ROUGE scores: {'rouge-1': {'f': 0.7608542618056445, 'p': 0.785724444400915, 'r': 0.7503060172317475}, 'rouge-2': {'f': 0.6322024945847413, 'p': 0.6517948470899967, 'r': 0.625484945969893}, 'rouge-l': {'f': 0.7486468138572879, 'p': 0.772900370326841, 'r': 0.7383761926703439}}
